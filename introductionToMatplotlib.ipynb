# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3, 4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11,22, 33, 55]
plt.plot(x,y)
plt.show()

# %%
# 1st Method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method
fig = plt.figure() # create a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # add some data
plt.show()

# %%
# 3rd method (recommended)
fig , ax = plt.subplots()
ax.plot(x, y); #add some data

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare  data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10, 10)) # width, height

# 3. Plot data
ax.plot(x, y)

# 4.Customize  plot
ax.set(title="Simple plot",
        xlabel="x-axis",
        ylabel="y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Hist
# * Subplots

# %%
# Plot the data and create a line plot
x = np.linspace(0, 10, 100)

x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use above data to create scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Create a plot from dictionary
nutButterPrices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12
                    }
fig, ax = plt.subplots()
ax.bar(nutButterPrices.keys(), nutButterPrices.values()); # (x, y)
ax.set(title="Butter store",
        ylabel="Prices ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nutButterPrices.keys()), list(nutButterPrices.values())); # (x, y)
ax.set(title="Butter store",
        ylabel="Prices ($)");

# %%
# Make some data  for histograms and plot it
import random
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))
# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nutButterPrices.keys(), nutButterPrices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                        ncols=2,
                        figsize=(10, 5))
# Plot to each different index 
ax[0, 0] .plot(x,x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nutButterPrices.keys(), nutButterPrices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
carSales = pd.read_csv("data/car-sales.csv")
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
                index = pd.date_range('1/1/2020',                       periods=1000))
ts = ts.cumsum() 

ts.plot();

# %%
carSales["Price"] = carSales["Price"].str.replace('[\$\, \.]', '')
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   40000
# 1   Honda    Red          87899      4   50000
# 2  Toyota   Blue          32549      3   70000
# 3     BMW  Black          11179      5  220000
# 4  Nissan  White         213095      4   35000
# 5  Toyota  Green          99213      4   45000
# 6   Honda   Blue          45698      4   75000
# 7   Honda   Blue          54738      4   70000
# 8  Toyota  White          60000      4   62500
# 9  Nissan  White          31600      4   97000

# %%
# Remove last 2 zeros
carSales["Price"] = carSales["Price"].str[:-1]

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
carSales["Sale Date"] = pd.date_range('1/1/2020', periods=len(carSales))
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
carSales['Total Sales'] =carSales["Price"].astype(int).cumsum()
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
type(carSales["Price"][0])
# Out:
# str

# %%
# Reassign price column to int
carSales.Price = carSales.Price.astype(int)

# Plot scatter plot with price as numeric
carSales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph
x = np.random.rand(10,4)

# Turn it to DF
df = pd.DataFrame(x, columns=['a','b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.007280  0.220338  0.232052  0.444834
# 1  0.699521  0.155639  0.821123  0.197438
# 2  0.979863  0.287165  0.313656  0.635524
# 3  0.504112  0.850882  0.755848  0.006421
# 4  0.974707  0.135029  0.769002  0.371078
# 5  0.808463  0.658281  0.275393  0.213888
# 6  0.233632  0.425882  0.009179  0.602838
# 7  0.798324  0.483973  0.291746  0.738674
# 8  0.693109  0.409677  0.432167  0.516250
# 9  0.356402  0.548942  0.312495  0.230567

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
carSales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# How about histograms?
carSales["Odometer (KM)"].plot.hist();

# %%
carSales["Odometer (KM)"].plot.hist(bins=20);

# %%
carSales["Odometer (KM)"].plot.boxplot("Odometer (KM)");
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-f30b0c1c9089> in <module>
# ----> 1 carSales["Odometer (KM)"].plot.boxplot("Odometer (KM)");
#
# AttributeError: 'PlotAccessor' object has no attribute 'boxplot'

# %%
type(carSales)
# Out:
# pandas.core.frame.DataFrame

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
carSales.boxplot(["Price", "Total Sales"])

# %%
carSales.plot.kde(bw_method=.1);
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-59-991ea5c26be3> in <module>
# ----> 1 carSales.plot.kde(bw_method=.1);
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1231             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1232         """
# -> 1233         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1234
#    1235     density = kde
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
heartDisease = pd.read_csv("data/heart-disease.csv")
heartDisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heartDisease.plot.hexbin(x="trestbps", y="chol");

# %%
heartDisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heartDisease["trestbps"].plot.hist();

# %%
heartDisease["age"].plot.hist(bins=10);

# %%
heartDisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heartDisease.plot.hist(figsize=(100, 100), subplots=True);

# %%
### Which one should you use? (pyplot vs matplotlib OO method)

# %%
# markets = pd.read_csv("data/markets.csv", sep=";")

# %%
markets
# Out:
#            Date                       Indices  Previous close  Day Open  \
# 0    2020/04/30  Dow Jones Industrial Average        24101.55  24490.37
# 1    2020/04/30    Brazil Bovespa Stock Index        81312.23  81312.89
# 2    2020/04/30           Santiago Index IPSA         3900.92   3900.92
# 3    2020/04/30                 S&P 500 INDEX         2863.39   2918.46
# 4    2020/04/30             Canada S&P/TSX 60          894.17    906.87
# ..          ...                           ...             ...       ...
# 613  2020/07/28    Brazil Bovespa Stock Index        10238.15  81023.80
# 614  2020/07/28           Santiago Index IPSA         2769.15   2769.15
# 615  2020/07/28                 S&P 500 INDEX         3215.63   3219.84
# 616  2020/07/28             Canada S&P/TSX 60          960.06    963.71
# 617  2020/07/28                           IPC        37357.46  37398.72
#
#      Day High       Day Low  LTP/Closing Prices
# 0    24764.77  24453.990000            24633.86
# ...

# %%
# type(markets)
# Out:
# pandas.core.frame.DataFrame

# %%
# markets.boxplot(column=["Day High", "Day Low", "Day Open", "LTP/Closing Prices"], grid=False)

# %%
# markets.columns.to_list()
# Out:
# ['Date',
#  'Indices',
#  'Previous close',
#  'Day Open',
#  'Day High',
#  'Day Low',
#  'LTP/Closing Prices']

# %%
# markets.to_csv("data/markets1.csv")

# %%
# markets.plot.line(x="Indices", y="Day High", figsize=(8,6));

# %%
markets
# Out:
#            Date                       Indices  Previous close  Day Open  \
# 0    2020/04/30  Dow Jones Industrial Average        24101.55  24490.37
# 1    2020/04/30    Brazil Bovespa Stock Index        81312.23  81312.89
# 2    2020/04/30           Santiago Index IPSA         3900.92   3900.92
# 3    2020/04/30                 S&P 500 INDEX         2863.39   2918.46
# 4    2020/04/30             Canada S&P/TSX 60          894.17    906.87
# ..          ...                           ...             ...       ...
# 613  2020/07/28    Brazil Bovespa Stock Index        10238.15  81023.80
# 614  2020/07/28           Santiago Index IPSA         2769.15   2769.15
# 615  2020/07/28                 S&P 500 INDEX         3215.63   3219.84
# 616  2020/07/28             Canada S&P/TSX 60          960.06    963.71
# 617  2020/07/28                           IPC        37357.46  37398.72
#
#      Day High       Day Low  LTP/Closing Prices
# 0    24764.77  24453.990000            24633.86
# ...

# %%
# markets.columns.to_list()
# Out:
# ['Date',
#  'Indices',
#  'Previous close',
#  'Day Open',
#  'Day High',
#  'Day Low',
#  'LTP/Closing Prices']

# %%
# Subplots option 2
# fig, ax = plt.subplots(nrows=2,
#                         ncols=2,
#                         figsize=(10, 5))
# Plot to each different index 
markets["Date"] = markets["Date"].apply(pd.to_datetime);
markets.set_index(['Date'])
# Out:
#                                  Indices  Previous close  Day Open  Day High  \
# Date
# 2020-04-30  Dow Jones Industrial Average        24101.55  24490.37  24764.77
# 2020-04-30    Brazil Bovespa Stock Index        81312.23  81312.89  83598.01
# 2020-04-30           Santiago Index IPSA         3900.92   3900.92   2827.13
# 2020-04-30                 S&P 500 INDEX         2863.39   2918.46   2954.86
# 2020-04-30             Canada S&P/TSX 60          894.17    906.87    922.16
# ...                                  ...             ...       ...       ...
# 2020-07-28    Brazil Bovespa Stock Index        10238.15  81023.80  85104.58
# 2020-07-28           Santiago Index IPSA         2769.15   2769.15   2808.18
# 2020-07-28                 S&P 500 INDEX         3215.63   3219.84   3241.43
# 2020-07-28             Canada S&P/TSX 60          960.06    963.71    969.26
# 2020-07-28                           IPC        37357.46  37398.72  37801.41
#
# ...

# %%
plt.rcParams["figure.figsize"] = (10, 5)
markets["Previous close"].plot(kind='bar');

# %%
import numpy as np
# import seaborn as sns

#Read cars data from csv
import pandas as pd
data = pd.read_csv("data/car-sales.csv")
data
#Import modules
# import plotly
from plotly import graph_objs as go

#Make Plotly figure
fig1 = go.Scatter(x=data["Odometer (KM)"],
                  y=data['price'],
                  mode='markers')

# Make Plot.ly Layout
mylayout = go.Layout(xaxis=dict(title="curb-weight"),
                     yaxis=dict( title="price"))

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-7c4cb24c50c5> in <module>
#       8 #Import modules
#       9 # import plotly
# ---> 10 from plotly import graph_objs as go
#      11
#      12 #Make Plotly figure
#
# ModuleNotFoundError: No module named 'plotly'
