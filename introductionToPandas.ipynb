# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Merc"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2      Merc
# dtype: object

# %%
#series = 1-dimensional

# %%
colors = pd.Series(["Red", "Blue", "Green"])
colors
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
# Dataframe = 2-dimensional
car_data = pd.DataFrame({"carMake": series, "Color":colors})

# %%
car_data
# Out:
#   carMake  Color
# 0     BMW    Red
# 1  Toyota   Blue
# 2    Merc  Green

# %%
# import Data
car_sales = pd.read_csv("data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("data/exported_car_sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("data/exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe data

# %%
# Attruute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
carColumns = car_sales.columns
carColumns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe() #only on int64 types
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Price"].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales #for all rows
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Viewing and selecting data

# %%
car_sales.head() #for top 5 rows
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail() #for bottom 5 rows
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc 
animals = pd.Series(["cat", "dog", "python", "panda", "snake"], 
                   index= [0,3, 9, 8, 3])
animals
# Out:
# 0       cat
# 3       dog
# 9    python
# 8     panda
# 3     snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'python'

# %%
# loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
# iloc refers to 
animals.iloc[:3]
# Out:
# 0       cat
# 3       dog
# 9    python
# dtype: object

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000 and car_sales["Make"] == "Toyota"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ef0f1b890523> in <module>
# ----> 1 car_sales[car_sales["Odometer (KM)"] > 100000 and car_sales["Make"] == "Toyota"]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales.Price= car_sales.Price.replace('[\$\, \.]', '').astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales.Price.plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
seats_column = pd.Series([5, 5, 5, 5, 5])
car_sales["SEATS"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales.SEATS.fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
# Column from python list
fuelEconomy = [7.5, 9,2, 5.0, 9.6, 8.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Economy per 100Km"] = fuelEconomy
car_sales.Economy.fillna(8.7, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy  \
# 0  Toyota  White         150043      4   4000.0    5.0      7.5
# 1   Honda    Red          87899      4   5000.0    5.0      9.0
# 2  Toyota   Blue          32549      3   7000.0    5.0      2.0
# 3     BMW  Black          11179      5  22000.0    5.0      5.0
# 4  Nissan  White         213095      4   3500.0    5.0      9.6
# 5  Toyota  Green          99213      4   4500.0    5.0      8.7
# 6   Honda   Blue          45698      4   7500.0    5.0      7.6
# 7   Honda   Blue          54738      4   7000.0    5.0      8.7
# 8  Toyota  White          60000      4   6250.0    5.0      3.0
# 9  Nissan  White          31600      4   9700.0    5.0      4.5
#
#    Economy per 100Km
# 0                7.5
# 1                9.0
# 2                2.0
# 3                5.0
# 4                9.6
# 5                8.7
# 6                7.6
# 7                8.7
# 8                3.0
# 9                4.5

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Economy per 100Km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy  \
# 0  Toyota  White         150043      4   4000.0    5.0      7.5
# 1   Honda    Red          87899      4   5000.0    5.0      9.0
# 2  Toyota   Blue          32549      3   7000.0    5.0      2.0
# 3     BMW  Black          11179      5  22000.0    5.0      5.0
# 4  Nissan  White         213095      4   3500.0    5.0      9.6
# 5  Toyota  Green          99213      4   4500.0    5.0      8.7
# 6   Honda   Blue          45698      4   7500.0    5.0      7.6
# 7   Honda   Blue          54738      4   7000.0    5.0      8.7
# 8  Toyota  White          60000      4   6250.0    5.0      3.0
# 9  Nissan  White          31600      4   9700.0    5.0      4.5
#
#    Economy per 100Km  Total fuel used
# 0                7.5        11253.225
# 1                9.0         7910.910
# 2                2.0          650.980
# 3                5.0          558.950
# 4                9.6        20457.120
# 5                8.7         8631.531
# 6                7.6         3473.048
# 7                8.7         4762.206
# 8                3.0         1800.000
# 9                4.5         1422.000

# %%
# Create column from single value
car_sales["No of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy  \
# 0  Toyota  White         150043      4   4000.0    5.0      7.5
# 1   Honda    Red          87899      4   5000.0    5.0      9.0
# 2  Toyota   Blue          32549      3   7000.0    5.0      2.0
# 3     BMW  Black          11179      5  22000.0    5.0      5.0
# 4  Nissan  White         213095      4   3500.0    5.0      9.6
# 5  Toyota  Green          99213      4   4500.0    5.0      8.7
# 6   Honda   Blue          45698      4   7500.0    5.0      7.6
# 7   Honda   Blue          54738      4   7000.0    5.0      8.7
# 8  Toyota  White          60000      4   6250.0    5.0      3.0
# 9  Nissan  White          31600      4   9700.0    5.0      4.5
#
#    Economy per 100Km  Total fuel used  No of Wheels
# 0                7.5        11253.225             4
# 1                9.0         7910.910             4
# 2                2.0          650.980             4
# 3                5.0          558.950             4
# 4                9.6        20457.120             4
# 5                8.7         8631.531             4
# 6                7.6         3473.048             4
# 7                8.7         4762.206             4
# 8                3.0         1800.000             4
# 9                4.5         1422.000             4

# %%
car_sales.dtypes
# Out:
# Make                  object
# Colour                object
# Odometer (KM)          int64
# Doors                  int64
# Price                float64
# SEATS                float64
# Economy              float64
# Economy per 100Km    float64
# Total fuel used      float64
# No of Wheels           int64
# dtype: object

# %%
car_sales = car_sales.drop("Economy", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                9.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                2.0
# 3     BMW  Black          11179      5  22000.0    5.0                5.0
# 4  Nissan  White         213095      4   3500.0    5.0                9.6
# 5  Toyota  Green          99213      4   4500.0    5.0                8.7
# 6   Honda   Blue          45698      4   7500.0    5.0                7.6
# 7   Honda   Blue          54738      4   7000.0    5.0                8.7
# 8  Toyota  White          60000      4   6250.0    5.0                3.0
# 9  Nissan  White          31600      4   9700.0    5.0                4.5
#
#    Total fuel used  No of Wheels
# 0        11253.225             4
# 1         7910.910             4
# 2          650.980             4
# 3          558.950             4
# 4        20457.120             4
# 5         8631.531             4
# 6         3473.048             4
# 7         4762.206             4
# 8         1800.000             4
# 9         1422.000             4

# %%
# randomizing data
carSalesShuffled = car_sales.sample(frac=1) 
carSalesShuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 2  Toyota   Blue          32549      3   7000.0    5.0                2.0
# 4  Nissan  White         213095      4   3500.0    5.0                9.6
# 5  Toyota  Green          99213      4   4500.0    5.0                8.7
# 8  Toyota  White          60000      4   6250.0    5.0                3.0
# 1   Honda    Red          87899      4   5000.0    5.0                9.0
# 9  Nissan  White          31600      4   9700.0    5.0                4.5
# 7   Honda   Blue          54738      4   7000.0    5.0                8.7
# 6   Honda   Blue          45698      4   7500.0    5.0                7.6
# 3     BMW  Black          11179      5  22000.0    5.0                5.0
#
#    Total fuel used  No of Wheels
# 0        11253.225             4
# 2          650.980             4
# 4        20457.120             4
# 5         8631.531             4
# 8         1800.000             4
# 1         7910.910             4
# 9         1422.000             4
# 7         4762.206             4
# 6         3473.048             4
# 3          558.950             4

# %%
carSalesShuffled = car_sales.sample(frac=1)
carSalesShuffled.reset_index(drop=True,inplace=True)

# %%
carSalesShuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy per 100Km  \
# 0     BMW  Black          11179      5  22000.0    5.0                5.0
# 1   Honda   Blue          45698      4   7500.0    5.0                7.6
# 2  Nissan  White         213095      4   3500.0    5.0                9.6
# 3  Toyota  Green          99213      4   4500.0    5.0                8.7
# 4  Toyota   Blue          32549      3   7000.0    5.0                2.0
# 5   Honda    Red          87899      4   5000.0    5.0                9.0
# 6   Honda   Blue          54738      4   7000.0    5.0                8.7
# 7  Toyota  White         150043      4   4000.0    5.0                7.5
# 8  Toyota  White          60000      4   6250.0    5.0                3.0
# 9  Nissan  White          31600      4   9700.0    5.0                4.5
#
#    Total fuel used  No of Wheels
# 0          558.950             4
# 1         3473.048             4
# 2        20457.120             4
# 3         8631.531             4
# 4          650.980             4
# 5         7910.910             4
# 6         4762.206             4
# 7        11253.225             4
# 8         1800.000             4
# 9         1422.000             4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0                7.5
# 1   Honda    Red          87899      4   5000.0    5.0                9.0
# 2  Toyota   Blue          32549      3   7000.0    5.0                2.0
# 3     BMW  Black          11179      5  22000.0    5.0                5.0
# 4  Nissan  White         213095      4   3500.0    5.0                9.6
# 5  Toyota  Green          99213      4   4500.0    5.0                8.7
# 6   Honda   Blue          45698      4   7500.0    5.0                7.6
# 7   Honda   Blue          54738      4   7000.0    5.0                8.7
# 8  Toyota  White          60000      4   6250.0    5.0                3.0
# 9  Nissan  White          31600      4   9700.0    5.0                4.5
#
#    Total fuel used  No of Wheels
# 0        11253.225             4
# 1         7910.910             4
# 2          650.980             4
# 3          558.950             4
# 4        20457.120             4
# 5         8631.531             4
# 6         3473.048             4
# 7         4762.206             4
# 8         1800.000             4
# 9         1422.000             4

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  SEATS  Economy per 100Km  \
# 0  Toyota  White      93776.875      4   4000.0    5.0                7.5
# 1   Honda    Red      54936.875      4   5000.0    5.0                9.0
# 2  Toyota   Blue      20343.125      3   7000.0    5.0                2.0
# 3     BMW  Black       6986.875      5  22000.0    5.0                5.0
# 4  Nissan  White     133184.375      4   3500.0    5.0                9.6
# 5  Toyota  Green      62008.125      4   4500.0    5.0                8.7
# 6   Honda   Blue      28561.250      4   7500.0    5.0                7.6
# 7   Honda   Blue      34211.250      4   7000.0    5.0                8.7
# 8  Toyota  White      37500.000      4   6250.0    5.0                3.0
# 9  Nissan  White      19750.000      4   9700.0    5.0                4.5
#
#    Total fuel used  No of Wheels
# 0        11253.225             4
# 1         7910.910             4
# 2          650.980             4
# 3          558.950             4
# 4        20457.120             4
# 5         8631.531             4
# 6         3473.048             4
# 7         4762.206             4
# 8         1800.000             4
# 9         1422.000             4
